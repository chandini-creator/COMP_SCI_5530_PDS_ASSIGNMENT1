# %% [markdown]
# Data Cleaning and Preprocessing

# %%
import pandas as pd
import os

# %%
from google.colab import files
uploaded = files.upload()  # Upload a CSV file manually
# Out:
#      <input type="file" id="files-d1db6343-914c-40b8-b1cd-dea680c232a5" name="files[]" multiple disabled
#         style="border:none" />
#      <output id="result-d1db6343-914c-40b8-b1cd-dea680c232a5">
#       Upload widget is only available when the cell has been executed in the
#       current browser session. Please rerun this cell to enable.
#       </output>
#       <script>// Copyright 2017 Google LLC
# //
# // Licensed under the Apache License, Version 2.0 (the "License");
# // you may not use this file except in compliance with the License.
# // You may obtain a copy of the License at
# //
# //      http://www.apache.org/licenses/LICENSE-2.0
# //
# // Unless required by applicable law or agreed to in writing, software
# // distributed under the License is distributed on an "AS IS" BASIS,
# // WITHOUT WARRANTIES OR CONDITIONS OF ANY KIND, either express or implied.
# // See the License for the specific language governing permissions and
# // limitations under the License.
#
# ...

# %%
# Define file paths
input_file = "raw_frailty_data.csv"  # If uploaded manually
output_file = "processed_frailty_data.csv"

# Load raw data
df = pd.read_csv(input_file)

# Remove missing values (if any)
df_cleaned = df.dropna()

# Save cleaned data
df_cleaned.to_csv(output_file, index=False)

print(" Data Cleaning Completed! Processed data saved as 'processed_frailty_data.csv'.")
df_cleaned.head()  # Display first few row
# Out:
#  Data Cleaning Completed! Processed data saved as 'processed_frailty_data.csv'.
#    Height  Weight  Age  Grip_Strength Frailty
# 0    65.8     112   30             30       N
# 1    71.5     136   19             31       N
# 2    69.4     153   45             29       N
# 3    68.2     142   22             28       Y
# 4    67.8     144   29             24       Y

# %%
df_cleaned
# Out:
#    Height  Weight  Age  Grip_Strength Frailty
# 0    65.8     112   30             30       N
# 1    71.5     136   19             31       N
# 2    69.4     153   45             29       N
# 3    68.2     142   22             28       Y
# 4    67.8     144   29             24       Y
# 5    68.7     123   50             26       N
# 6    69.8     141   51             22       Y
# 7    70.1     136   23             20       Y
# 8    67.9     112   17             19       N
# 9    66.8     120   39             31       N
